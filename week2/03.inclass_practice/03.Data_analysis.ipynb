# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
import pandas as pd
import seaborn as sns
# %matplotlib inline

# 한글 폰트 깨지지 않게 하기
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df_fitness = pd.read_csv("../01.files/01.Bigdata_basic/FITNESS.csv", encoding='euc-kr')
df_fitness
# Out:
#         NAME GENDER  AGE AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  \
# 0      Donna     여성   42      40대   68.15  59.571     8.17       166
# 1     Gracie     여성   38      30대   81.87  60.055     8.63       170
# 2     Luanne     여성   43      40대   85.84  54.297     8.65       156
# 3       Mimi     여성   50      50대   70.87  54.625     8.92       146
# 4      Chris     남성   49      40대   81.42  49.156     8.95       180
# 5      Allen     남성   38      30대   89.02  49.874     9.22       178
# 6      Nancy     여성   49      40대   76.32  48.673     9.40       186
# 7      Patty     여성   52      50대   76.32  45.441     9.63       164
# 8    Suzanne     여성   57      50대   59.08  50.545     9.93       148
# 9     Teresa     여성   51      50대   77.91  46.672    10.00       162
# 10       Bob     남성   39      30대   75.07  45.313    10.07       185
# 11  Harriett     여성   49      40대   73.37  50.388    10.08       168
# 12      Jane     여성   44      40대   73.03  50.541    10.13       168
# 13    Harold     남성   48      40대   91.63  46.774    10.25       162
# 14     Sammy     남성   54      50대   83.12  51.855    10.33       166
# 15     Buffy     여성   52      50대   73.71  45.790    10.47       186
# 16     Trent     남성   38      30대   82.78  47.467    10.50       170
# 17    Jackie     여성   47      40대   79.15  47.273    10.60       162
# 18     Ralph     남성   43      40대   81.19  49.091    10.85       162
# 19      Jack     남성   51      50대   69.63  40.836    10.95       168
# 20     Annie     여성   51      50대   67.25  45.118    11.08       172
# 21      Kate     여성   45      40대   66.45  44.754    11.12       176
# 22      Carl     남성   54      50대   79.38  46.080    11.17       156
# 23       Don     남성   44      40대   89.47  44.609    11.37       178
# 24     Effie     여성   48      40대   61.24  47.920    11.50       170
# 25    George     남성   37      30대   77.45  44.811    11.63       176
# 26      Iris     여성   39      30대   75.98  45.681    11.95       176
# 27      Mark     남성   57      50대   73.37  39.407    12.63       174
# 28     Steve     남성   54      50대   91.63  39.203    12.88       168
# 29    Vaughn     남성   44      40대   81.42  39.442    13.08       174
# 30   William     남성   45      40대   87.66  37.388    14.03       186
#
#     RSTPULSE  MAXPULSE
# 0         40       172
# 1         48       186
# 2         45       168
# 3         48       155
# 4         44       185
# 5         55       180
# 6         56       188
# 7         48       166
# 8         49       155
# 9         48       168
# 10        62       185
# 11        67       168
# 12        45       168
# 13        48       164
# 14        50       170
# 15        59       188
# 16        53       172
# 17        47       164
# 18        64       170
# 19        57       172
# 20        48       172
# 21        51       176
# 22        62       165
# 23        62       182
# 24        52       176
# 25        58       176
# 26        70       180
# 27        58       176
# 28        44       172
# 29        63       176
# 30        56       192

# %%
df_trade = pd.read_csv("../01.files/01.Bigdata_basic/환율.csv", parse_dates = ["APPL_DATE"]) #parse_dates 날짜를 데이트타임으로 바꿔주는 역할
df_trade.head()
# Out:
#   CURRENCY  APPL_DATE  STD_RATE  USD_CONV_DATE
# 0      CNY 2016-01-01    181.48         0.1541
# 1      JPY 2016-01-01    976.99         0.8294
# 2      USD 2016-01-01   1178.00         1.0000
# 3      CNY 2016-01-02    181.48         0.1541
# 4      JPY 2016-01-02    976.99         0.8294

# %%
sns.countplot(x='GENDER', data = df_fitness)
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(x = "AGEGROUP", data =df_fitness)
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %%
sns.countplot(x = "AGEGROUP", hue = "GENDER", data = df_fitness)
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='count'>

# %%
index = df_fitness['GENDER'].unique()
value = df_fitness['GENDER'].value_counts()
#value
plt.bar(index, value)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.histplot(data = df_fitness, x = "OXY",bins = 15, kde=True) #bins = 간격 , kde = 커널밀도곡선
# Out:
# <Axes: xlabel='OXY', ylabel='Count'>

# %%
sns.distplot(df_fitness['OXY']) #밀도랑 히스토 같이 그리기
# Out:
# /var/folders/hf/f987bl1j4tz9tt0z606pjnfr0000gn/T/ipykernel_1920/3678613603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_fitness['OXY']) #밀도랑 히스토 같이 그리기
# <Axes: xlabel='OXY', ylabel='Density'>

# %%
df_fitness.hist(figsize=(10,7))
# Out:
# array([[<Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'WEIGHT'}>,
#         <Axes: title={'center': 'OXY'}>],
#        [<Axes: title={'center': 'RUNTIME'}>,
#         <Axes: title={'center': 'RUNPULSE'}>,
#         <Axes: title={'center': 'RSTPULSE'}>],
#        [<Axes: title={'center': 'MAXPULSE'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.hist(df_fitness[df_fitness["GENDER"] == "남성"]["OXY"], label = '남성', alpha = 1.0)
plt.hist(df_fitness[df_fitness["GENDER"] == "여성"]["OXY"], label = '남성', alpha = 0.5) # alpha = 투명도
# Out:
# (array([5., 2., 2., 3., 0., 0., 2., 0., 0., 2.]),
#  array([44.754 , 46.2841, 47.8142, 49.3443, 50.8744, 52.4045, 53.9346,
#         55.4647, 56.9948, 58.5249, 60.055 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(y = 'OXY', x = 'AGEGROUP', data = df_fitness)
# Out:
# <Axes: xlabel='AGEGROUP', ylabel='OXY'>

# %%
sns.boxplot(y='OXY', x='GENDER', hue = 'AGEGROUP', data = df_fitness)
# Out:
# <Axes: xlabel='GENDER', ylabel='OXY'>

# %%
df_count = df_fitness.groupby(['GENDER']).size()
df_count.plot.pie(y="OXY", autopct = "%.1f%%")
# Out:
# <Axes: >

# %%
df_count = df_fitness.groupby(["GENDER", "AGEGROUP"]).size()
df_count.plot.pie(y="OXY", autopct = '%.1f%%', explode=[0,0,0,0,0.2,0]) #explode : 중심으로부터 얼마나 멀어질지 측정하는
# Out:
# <Axes: >

# %%
# scatter, 회귀분석등에 자주 이용됨
sns.scatterplot(x="RUNTIME", y = "OXY", hue = "GENDER", style = "GENDER", data = df_fitness)
# Out:
# <Axes: xlabel='RUNTIME', ylabel='OXY'>

# %%
sns.lmplot(data = df_fitness, x = "RUNTIME", y = "OXY", hue = "GENDER")

# %%
sns.pairplot(df_fitness). # 각 피쳐별 관계를 나타냄, 선형관계가 보이는것도 있음

# %%
sns.pairplot(df_fitness, y_vars=["OXY"], x_vars = ["RUNPULSE", "MAXPULSE", "RUNTIME"])

# %%
df_currency = pd.read_csv("../01.files/01.Bigdata_basic/환율.csv", encoding = 'euc-kr', parse_dates=['APPL_DATE'])

df_currency_pivot = df_currency.pivot(index = "APPL_DATE", columns = "CURRENCY", values = "STD_RATE")
df_currency_pivot.head()
# Out:
# CURRENCY       CNY     JPY     USD
# APPL_DATE
# 2016-01-01  181.48  976.99  1178.0
# 2016-01-02  181.48  976.99  1178.0
# 2016-01-03  181.48  976.99  1178.0
# 2016-01-04  181.10  992.62  1184.0
# 2016-01-05  181.94  993.00  1185.0

# %%
df_currency_pivot["CNY"].plot()
df_currency_pivot[["JPY","USD"]].plot()
# Out:
# <Axes: xlabel='APPL_DATE'>

# %%
df_agg = df_fitness.groupby(["GENDER","AGEGROUP"], as_index=False)['OXY'].agg("mean")
df_pivot = df_agg.pivot("GENDER", "AGEGROUP", "OXY")
sns.heatmap(df_pivot, cmap="Blues")
# Out:
# /var/folders/hf/f987bl1j4tz9tt0z606pjnfr0000gn/T/ipykernel_1920/1853497078.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_pivot = df_agg.pivot("GENDER", "AGEGROUP", "OXY")
# <Axes: xlabel='AGEGROUP', ylabel='GENDER'>

# %%
df_pivot
# Out:
# AGEGROUP       30대        40대        50대
# GENDER
# 남성        46.86625  44.410000  43.476200
# 여성        52.86800  50.427125  48.031833

# %%
df_corr = df_fitness.corr()
sns.heatmap(df_corr, annot = True, cmap= "viridis")
# Out:
# /var/folders/hf/f987bl1j4tz9tt0z606pjnfr0000gn/T/ipykernel_1920/424374078.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df_fitness.corr()
# <Axes: >

# %%
sns.kdeplot(data = df_fitness, x="RUNTIME", y = "OXY", shade = False) #shade = 색 채우냐 안채우냐
# Out:
# /var/folders/hf/f987bl1j4tz9tt0z606pjnfr0000gn/T/ipykernel_1920/192678081.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df_fitness, x="RUNTIME", y = "OXY", shade = False)
# <Axes: xlabel='RUNTIME', ylabel='OXY'>

# %%
pd.plotting.parallel_coordinates(df_fitness, "GENDER", cols = ["OXY","WEIGHT","RSTPULSE"], colormap = "Accent")
# Out:
# <Axes: >

# %%
df_count = df_fitness["AGEGROUP"].value_counts()
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (13,10))
plt.tight_layout(w_pad = 5, h_pad = 5)

axes[0,0].hist(df_fitness["OXY"])
axes[0,0].set_title("Histogram",fontsize = 15)
axes[0,0].set_xlabel("혈당 산소 요구량", fontsize = 12)

axes[0,1].pie(df_count, labels = df_count.index.tolist(), autopct = "%.1f%%")
axes[0,1].set_title("Pie chart", fontsize = 15)
axes[0,1].set_xlabel("연령대", fontsize = 12)

axes[1,0].plot("RUNTIME", "RUNPULSE",data = df_fitness, label = "맥박(운동)")
axes[1,0].plot("RUNTIME", "OXY",data = df_fitness, label = "혈당 산소요구량")
axes[1,0].set_title("Trend", fontsize = 15)
axes[1,0].set_xlabel("운동 시간", fontsize = 12)

axes[1,1].scatter("RUNPULSE", "OXY", data = df_fitness)
axes[1,1].set_title("Scatter", fontsize = 15)
axes[1,1].set_xlabel("맥박(운동)", fontsize = 12)
axes[1,1].set_ylabel("혈당 산소요구량", fontsize = 12)
# Out:
# Text(673.0176767676767, 0.5, '혈당 산소요구량')
